# %%
import pandas as pd
import re

# %%
data = pd.read_csv('test3.csv')

# %%
data
# Out:
#      duration         mmr result server                team_1  \
# 0       11分2秒  Challenger      敗   eune        雷茲,艾克,姬亞娜,燼,娜米
# 1       11分2秒  Challenger     勝利   eune    賽勒斯,卡力斯,卡薩丁,圖奇,塔里克
# 2       11分2秒  Challenger      敗   eune  墨菲特,努努和威朗普,拉克絲,艾希,珍娜
# 3       11分2秒  Challenger      敗   eune    卡特蓮娜,雷葛爾,凱能,寇格魔,露璐
# 4      11分34秒  Challenger      敗    las  弗拉迪米爾,伊莉絲,犽凝,崔絲塔娜,巴德
# ...       ...         ...    ...    ...                   ...
# 5003   44分45秒  Challenger      敗     na     弗力貝爾,卡力斯,星朵拉,燼,露璐
# 5004   44分45秒  Challenger      敗     na     雷尼克頓,奈德麗,阿卡莉,燼,賽特
# 5005   44分45秒  Challenger     勝利     na   賈克斯,葛雷夫,雷茲,亞菲利歐,雷歐娜
# 5006   45分29秒  Challenger      敗    lan      札克,卡力斯,阿卡莉,凱莎,潘森
# 5007   45分29秒  Challenger     勝利    lan       菲歐拉,卡力斯,艾克,燼,娜米
#
#                     team_2         timestamp
# 0      葵恩,弗力貝爾,星朵拉,伊澤瑞爾,珍娜  2020/11/10 19:10
# 1     賈克斯,奈德麗,奧莉安娜,伊澤瑞爾,悠咪   2020/11/8 19:02
# 2       卡蜜兒,卡力斯,雷茲,崔絲塔娜,露璐   2020/11/5 23:23
# ...

# %%
secondDuration = []

# %%
for time in data['duration']:
    timeList = time.replace('分',' ').replace('秒',' ').split()
    secondsTime = timeList[0] * 60 + timeList[1]
    print(timeList)
#     secondDuration.append(secondsTime)

# %%
data['secondDuration'] = secondDuration
data
# Out:
#      duration         mmr result server                team_1  \
# 0       11分2秒  Challenger      敗   eune        雷茲,艾克,姬亞娜,燼,娜米
# 1       11分2秒  Challenger     勝利   eune    賽勒斯,卡力斯,卡薩丁,圖奇,塔里克
# 2       11分2秒  Challenger      敗   eune  墨菲特,努努和威朗普,拉克絲,艾希,珍娜
# 3       11分2秒  Challenger      敗   eune    卡特蓮娜,雷葛爾,凱能,寇格魔,露璐
# 4      11分34秒  Challenger      敗    las  弗拉迪米爾,伊莉絲,犽凝,崔絲塔娜,巴德
# ...       ...         ...    ...    ...                   ...
# 5003   44分45秒  Challenger      敗     na     弗力貝爾,卡力斯,星朵拉,燼,露璐
# 5004   44分45秒  Challenger      敗     na     雷尼克頓,奈德麗,阿卡莉,燼,賽特
# 5005   44分45秒  Challenger     勝利     na   賈克斯,葛雷夫,雷茲,亞菲利歐,雷歐娜
# 5006   45分29秒  Challenger      敗    lan      札克,卡力斯,阿卡莉,凱莎,潘森
# 5007   45分29秒  Challenger     勝利    lan       菲歐拉,卡力斯,艾克,燼,娜米
#
#                     team_2         timestamp  \
# 0      葵恩,弗力貝爾,星朵拉,伊澤瑞爾,珍娜  2020/11/10 19:10
# 1     賈克斯,奈德麗,奧莉安娜,伊澤瑞爾,悠咪   2020/11/8 19:02
# 2       卡蜜兒,卡力斯,雷茲,崔絲塔娜,露璐   2020/11/5 23:23
# ...

# %%
timeList = test.replace('分',' ').replace('秒',' ').split()
b
# Out:
# ['11', '2']

# %%
secondTime = sum([int(i) for i in timeList if type(i)== int or i.isdigit()])
# Out:
# 13
